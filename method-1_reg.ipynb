# %%
import numpy as np
import pandas as pd
import imblearn                                      
from imblearn.over_sampling import RandomOverSampler
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.impute import KNNImputer

# %%
data = pd.read_csv('initial_preprocessing_reg.csv')
data = data[data['DAS28-CRP 3m'].notnull()]    ### We don't need unknown category for method-1

# %%
data
# Out:
#      grp  Type I IFN activity  IFNβ activity final  IFNα activity final  \
# 0      0             0.000000                  NaN                  NaN
# 1      1             0.814954             0.714954             0.714954
# 2      1             4.582632             2.869955             4.482632
# 3      1             0.015811                  NaN                  NaN
# 4      2             0.683486             0.583486             0.583486
# ..   ...                  ...                  ...                  ...
# 291    2             0.379131             0.279131             0.279131
# 292    1             0.000000                  NaN                  NaN
# 293    2             0.000000                  NaN                  NaN
# 294    2             0.000000                  NaN                  NaN
# 295    0             0.000000                  NaN                  NaN
#
#      IFNβ/α ratio final  pres_imuran  pres_minocin  nonpresNSAIDs_use  \
# 0                   NaN          0.0           0.0                0.0
# 1              1.000000          0.0           0.0                1.0
# 2              0.640239          0.0           0.0                0.0
# 3                   NaN          0.0           0.0                NaN
# 4              1.000000          0.0           0.0                NaN
# ..                  ...          ...           ...                ...
# 291            1.000000          0.0           0.0                1.0
# 292                 NaN          0.0           0.0                1.0
# 293                 NaN          0.0           0.0                1.0
# 294                 NaN          0.0           0.0                1.0
# 295                 NaN          0.0           0.0                NaN
#
#      NSAIDs_use  tender_jts_28  ...  tender_jts_28_BL  swollen_jts_28_BL  \
# 0           0.0            0.0  ...                 5                  3
# 1           NaN            1.0  ...                 3                  3
# 2           0.0            5.0  ...                 2                  6
# 3           NaN           14.0  ...                 3                  9
# 4           NaN            2.0  ...                14                 13
# ..          ...            ...  ...               ...                ...
# 291         NaN            0.0  ...                 0                  9
# 292         NaN            2.0  ...                 8                  7
# 293         NaN            2.0  ...                 2                  6
# 294         NaN            0.0  ...                 5                  5
# 295         NaN            1.0  ...                 4                  4
#
#      md_global_assess_BL  pt_global_assess_BL  di_BL  pt_pain_BL  \
# 0                   35.0                 10.0   0.00        10.0
# 1                   35.0                 17.0   0.25        25.0
# 2                   40.0                 10.0   0.00         5.0
# 3                   55.0                 50.0   0.25        60.0
# 4                   65.0                 20.0   0.25        65.0
# ..                   ...                  ...    ...         ...
# 291                 70.0                 15.0   0.00        65.0
# 292                 55.0                 80.0   1.00        80.0
# 293                 35.0                 50.0   0.00        15.0
# 294                 35.0                 15.0   0.00        15.0
# 295                 70.0                 93.0   1.50       100.0
#
#      usresultsCRP_BL  usresultsIgA_BL  usresultsIgG_BL  usresultsIgM_BL
# 0               4.41            284.0           1640.0             94.0
# 1               1.19            207.0           1010.0             56.0
# 2               0.40            190.0            657.0            100.0
# 3               1.00             44.0            948.0             51.0
# 4               0.25            155.0            824.0             43.0
# ..               ...              ...              ...              ...
# 291             6.02            125.0           1000.0             77.0
# 292             7.33            353.0            859.0            211.0
# 293            22.36            266.0           1330.0            253.0
# 294             0.92            163.0           1500.0             44.0
# 295             3.90            198.0           1730.0            244.0
#
# [278 rows x 64 columns]

# %%
rs = 1337
X = data.drop('DAS28-CRP 3m',1)                            ### Dividing the dataframe into X and y set
y = data['DAS28-CRP 3m']
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=0.1,random_state = rs)
# Out:
# <ipython-input-63-6aac00e6f16e>:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   X = data.drop('DAS28-CRP 3m',1)                            ### Dividing the dataframe into X and y set

# %%
X_train
# Out:
#      grp  Type I IFN activity  IFNβ activity final  IFNα activity final  \
# 91     1             2.966271             1.052589             2.424268
# 125    0             1.900473             1.852377             1.800473
# 57     2             2.095485             0.786182             1.995485
# 167    2             0.000000                  NaN                  NaN
# 179    0             0.000000                  NaN                  NaN
# ..   ...                  ...                  ...                  ...
# 292    1             0.000000                  NaN                  NaN
# 174    2             1.633918             1.533918             1.533918
# 247    2             0.363487             0.263487             0.263487
# 200    2             1.848624             1.748624             1.683421
# 158    2             8.067865             7.967865             7.967865
#
#      IFNβ/α ratio final  pres_imuran  pres_minocin  nonpresNSAIDs_use  \
# 91             0.434189          0.0           0.0                NaN
# 125            1.028828          0.0           0.0                0.0
# 57             0.393980          0.0           0.0                1.0
# 167                 NaN          0.0           0.0                NaN
# 179                 NaN          0.0           0.0                NaN
# ..                  ...          ...           ...                ...
# 292                 NaN          0.0           0.0                1.0
# 174            1.000000          0.0           0.0                NaN
# 247            1.000000          0.0           0.0                NaN
# 200            1.038732          0.0           0.0                NaN
# 158            1.000000          0.0           0.0                0.0
#
#      NSAIDs_use  tender_jts_28  ...  tender_jts_28_BL  swollen_jts_28_BL  \
# 91          1.0            2.0  ...                 7                  2
# 125         0.0            1.0  ...                19                 19
# 57          NaN            0.0  ...                 8                  6
# 167         1.0           20.0  ...                17                  4
# 179         NaN            5.0  ...                11                 13
# ..          ...            ...  ...               ...                ...
# 292         NaN            2.0  ...                 8                  7
# 174         1.0            5.0  ...                28                  2
# 247         1.0            0.0  ...                10                  1
# 200         1.0            5.0  ...                10                  4
# 158         0.0            2.0  ...                 4                  4
#
#      md_global_assess_BL  pt_global_assess_BL  di_BL  pt_pain_BL  \
# 91                  40.0                 70.0  1.000        70.0
# 125                 90.0                 88.0  0.750        88.0
# 57                  40.0                 50.0  0.875        80.0
# 167                 40.0                 35.0  0.500        45.0
# 179                 50.0                 45.0  0.500        90.0
# ..                   ...                  ...    ...         ...
# 292                 55.0                 80.0  1.000        80.0
# 174                 40.0                 60.0  2.000        70.0
# 247                 30.0                 60.0  0.250        50.0
# 200                 60.0                 25.0  0.250        50.0
# 158                 60.0                 55.0  0.375        40.0
#
#      usresultsCRP_BL  usresultsIgA_BL  usresultsIgG_BL  usresultsIgM_BL
# 91             31.71            179.0            761.0             55.0
# 125            18.83            230.0           1290.0             47.0
# 57             40.83            512.0           1420.0            246.0
# 167             1.27            164.0            753.0             66.0
# 179             2.24            152.0            709.0            300.0
# ..               ...              ...              ...              ...
# 292             7.33            353.0            859.0            211.0
# 174             8.50            157.0           1210.0             27.0
# 247             9.16              NaN              NaN              NaN
# 200             5.79            382.0           1070.0            166.0
# 158            14.17            331.0           1370.0             57.0
#
# [250 rows x 63 columns]

# %%
Y_train
# Out:
# 91     3.011960
# 125    2.721467
# 57     1.961178
# 167    4.876500
# 179    3.322725
#          ...
# 292    3.685886
# 174    4.188581
# 247    2.098190
# 200    3.230426
# 158    2.959915
# Name: DAS28-CRP 3m, Length: 250, dtype: float64

# %%
imputer = KNNImputer(n_neighbors=15)                     ### Imputing the null values using KNN with neighbors as 15
fit_train = imputer.fit(X_train)
imput_train = fit_train.transform(X_train)
c = list(X_train.columns)
imput_train_df = pd.DataFrame(imput_train, columns = c)

# %%
imput_test = fit_train.transform(X_test)                 ### Imputing the test set using the training set
c = list(X_test.columns)
imput_test_df = pd.DataFrame(imput_test, columns = c)

# %%
imput_train_df
# Out:
#      grp  Type I IFN activity  IFNβ activity final  IFNα activity final  \
# 0    1.0             2.966271             1.052589             2.424268
# 1    0.0             1.900473             1.852377             1.800473
# 2    2.0             2.095485             0.786182             1.995485
# 3    2.0             0.000000             1.902159             2.751817
# 4    0.0             0.000000             1.415869             2.435678
# ..   ...                  ...                  ...                  ...
# 245  1.0             0.000000             1.520931             2.568490
# 246  2.0             1.633918             1.533918             1.533918
# 247  2.0             0.363487             0.263487             0.263487
# 248  2.0             1.848624             1.748624             1.683421
# 249  2.0             8.067865             7.967865             7.967865
#
#      IFNβ/α ratio final  pres_imuran  pres_minocin  nonpresNSAIDs_use  \
# 0              0.434189          0.0           0.0           0.733333
# 1              1.028828          0.0           0.0           0.000000
# 2              0.393980          0.0           0.0           1.000000
# 3              0.818473          0.0           0.0           0.666667
# 4              0.720669          0.0           0.0           0.666667
# ..                  ...          ...           ...                ...
# 245            0.617287          0.0           0.0           1.000000
# 246            1.000000          0.0           0.0           0.800000
# 247            1.000000          0.0           0.0           0.733333
# 248            1.038732          0.0           0.0           0.666667
# 249            1.000000          0.0           0.0           0.000000
#
#      NSAIDs_use  tender_jts_28  ...  tender_jts_28_BL  swollen_jts_28_BL  \
# 0      1.000000            2.0  ...               7.0                2.0
# 1      0.000000            1.0  ...              19.0               19.0
# 2      0.466667            0.0  ...               8.0                6.0
# 3      1.000000           20.0  ...              17.0                4.0
# 4      0.733333            5.0  ...              11.0               13.0
# ..          ...            ...  ...               ...                ...
# 245    0.800000            2.0  ...               8.0                7.0
# 246    1.000000            5.0  ...              28.0                2.0
# 247    1.000000            0.0  ...              10.0                1.0
# 248    1.000000            5.0  ...              10.0                4.0
# 249    0.000000            2.0  ...               4.0                4.0
#
#      md_global_assess_BL  pt_global_assess_BL  di_BL  pt_pain_BL  \
# 0                   40.0                 70.0  1.000        70.0
# 1                   90.0                 88.0  0.750        88.0
# 2                   40.0                 50.0  0.875        80.0
# 3                   40.0                 35.0  0.500        45.0
# 4                   50.0                 45.0  0.500        90.0
# ..                   ...                  ...    ...         ...
# 245                 55.0                 80.0  1.000        80.0
# 246                 40.0                 60.0  2.000        70.0
# 247                 30.0                 60.0  0.250        50.0
# 248                 60.0                 25.0  0.250        50.0
# 249                 60.0                 55.0  0.375        40.0
#
#      usresultsCRP_BL  usresultsIgA_BL  usresultsIgG_BL  usresultsIgM_BL
# 0              31.71            179.0       761.000000        55.000000
# 1              18.83            230.0      1290.000000        47.000000
# 2              40.83            512.0      1420.000000       246.000000
# 3               1.27            164.0       753.000000        66.000000
# 4               2.24            152.0       709.000000       300.000000
# ..               ...              ...              ...              ...
# 245             7.33            353.0       859.000000       211.000000
# 246             8.50            157.0      1210.000000        27.000000
# 247             9.16            295.2      1084.466667       138.266667
# 248             5.79            382.0      1070.000000       166.000000
# 249            14.17            331.0      1370.000000        57.000000
#
# [250 rows x 63 columns]

# %%
labels = ['grp','gender','final_education','race_grp','newsmoker','drinker','ara_func_class']     ### normalizing the dataset

for i in imput_train_df.columns:
    if i not in labels:
        mean = imput_train_df[i].mean()
        std = imput_train_df[i].std()
        imput_train_df[i] = (imput_train_df[i] - mean) / std
        imput_test_df[i] = (imput_test_df[i] - mean) / std

# %%
labels = ['pres_imuran','pres_minocin','num_tnf','num_nontnf','hxunstab_ang','pres_minocin_BL','ethnicity','hxstroke','pres_imuran_BL']    #### This columns has same value for every row so when I divide by mean and std the value goes to infinity
for i in labels:
    imput_train_df = imput_train_df.drop(i,1)
    imput_test_df = imput_test_df.drop(i,1)
# Out:
# <ipython-input-50-649ae34e813e>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   imput_train_df = imput_train_df.drop(i,1)
# <ipython-input-50-649ae34e813e>:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   imput_test_df = imput_test_df.drop(i,1)

# %%
Y_train1 = Y_train.reset_index()
Y_train1 = Y_train1.drop(columns=['index'])

# %%
Y_train1
# Out:
#      DAS28-CRP 3m
# 0        3.011960
# 1        2.721467
# 2        1.961178
# 3        4.876500
# 4        3.322725
# ..            ...
# 245      3.685886
# 246      4.188581
# 247      2.098190
# 248      3.230426
# 249      2.959915
#
# [250 rows x 1 columns]

# %%
Y_train1 = Y_train.reset_index()
Y_train1 = Y_train1.drop(columns=['index'])
imput_train_df['y'] = Y_train1
imput_train_df.to_csv('train_method1_rg.csv', index = False)

# %%
Y_test1 = Y_test.reset_index()
Y_test1 = Y_test1.drop(columns=['index'])
imput_test_df['y'] = Y_test1 
imput_test_df.to_csv('test_method1_rg.csv', index = False)

# %%
imput_train_df['y'].isnull().sum()
# Out:
# 0
